# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd().parent / "python_example"))
from api_client import RPR_ShowConsoleMsg
from api_client import client, hold

# %%
client.connect()

# %% [markdown]
# ## with hold

# %%
# %%time
with hold():
    for num in range(100):
        num += 1
        RPR_ShowConsoleMsg(f"Hello REAPER uses! loop counts {num}\n")
# Out:
# CPU times: user 3.14 ms, sys: 177 μs, total: 3.31 ms
# Wall time: 8.82 ms

# %% [markdown]
# ## no hold

# %%
# %%time
for num in range(100):
    num += 1
    RPR_ShowConsoleMsg(f"Hello REAPER uses! loop counts {num}\n")
# Out:
# CPU times: user 6.69 ms, sys: 1.1 ms, total: 7.79 ms
# Wall time: 3.73 s
